# %%
import numpy as np
import xarray as xr
import dask
import intake
import pandas as pd
import os
from collections import defaultdict
from tqdm.autonotebook import tqdm
from xmip.utils import google_cmip_col
from cmip_catalogue_operations import reduce_cat_to_max_num_realizations, drop_vars_from_cat
import typing
import itertools
# Out:
# /tmp/ipykernel_3807/897296857.py:8: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
#borrowed from intake-esm so that I can apply this on the concatenation of different data catalogues
def search_apply_require_all_on(
    *,
    df: pd.DataFrame,
    query: dict[str, typing.Any],
    require_all_on: typing.Union[str, list[typing.Any]],
    columns_with_iterables: set = None,
) -> pd.DataFrame:
    _query = query.copy()
    
    for column in require_all_on:
        _query.pop(column, None)
    
    keys = list(_query.keys())
    grouped = df.groupby(require_all_on)
    values = [tuple(v) for v in _query.values()]
    condition = set(itertools.product(*values))
    query_results = []
    
    for _, group in grouped:
        group_for_index = group
        # Unpack iterables to get testable index.
        for column in (columns_with_iterables or set()).intersection(keys):
            group_for_index = unpack_iterable_column(group_for_index, column)

        index = group_for_index.set_index(keys).index
        if not isinstance(index, pd.MultiIndex):
            index = {(element,) for element in index.to_list()}
        else:
            index = set(index.to_list())
        if condition.issubset(index):  # with iterables we could have more then requested
            query_results.append(group)

    if query_results:
        return pd.concat(query_results).reset_index(drop=True)

    return pd.DataFrame(columns=df.columns)

# %%
ccol = intake.open_esm_datastore(
    "https://storage.googleapis.com/leap-persistent-ro/data-library/catalogs/cmip6-test/leap-pangeo-cmip6-noqc-test.json"
)
variable = 'sfcWind' #variable to obtain data for
query_vars = ['sfcWind','pr','psl'] #variables models simulations are required to provide
experiments = ['historical','ssp585']

cat_ssp245 = ccol.search(experiment_id=['historical','ssp585'],table_id='day')

# %%
cat_ssp245.df
# Out:
#      activity_id       institution_id      source_id experiment_id  \
# 0           CMIP                MIROC         MIROC6    historical
# 1    ScenarioMIP  EC-Earth-Consortium      EC-Earth3        ssp585
# 2    ScenarioMIP                MPI-M  MPI-ESM1-2-LR        ssp585
# 3           CMIP  EC-Earth-Consortium      EC-Earth3    historical
# 4           CMIP  EC-Earth-Consortium      EC-Earth3    historical
# ..           ...                  ...            ...           ...
# 310         CMIP  EC-Earth-Consortium      EC-Earth3    historical
# 311         CMIP  EC-Earth-Consortium      EC-Earth3    historical
# 312  ScenarioMIP                MIROC     MIROC-ES2L        ssp585
# 313         CMIP                MPI-M  MPI-ESM1-2-LR    historical
# 314  ScenarioMIP                MIROC     MIROC-ES2L        ssp585
#
#       member_id table_id variable_id grid_label  \
# 0     r35i1p1f1      day         psl         gn
# 1    r132i1p1f1      day          pr         gr
# 2     r29i1p1f1      day         psl         gn
# 3    r108i1p1f1      day          pr         gr
# 4    r139i1p1f1      day         psl         gr
# ..          ...      ...         ...        ...
# 310  r121i1p1f1      day         psl         gr
# 311  r139i1p1f1      day          pr         gr
# 312    r1i1p1f2      day     sfcWind         gn
# 313   r21i1p1f1      day     sfcWind         gn
# 314    r8i1p1f2      day         psl         gn
#
#                                                 zstore  dcpp_init_year  \
# 0    gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 1    gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 2    gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 3    gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 4    gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# ..                                                 ...             ...
# 310  gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 311  gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 312  gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 313  gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
# 314  gs://leap-persistent-ro/data-library/cmip6-tes...             NaN
#
#        version
# 0    v20200519
# 1    v20200412
# 2    v20210901
# 3    v20200412
# 4    v20200412
# ..         ...
# 310  v20200412
# 311  v20200412
# 312  v20220530
# 313  v20210901
# 314  v20220204
#
# [315 rows x 11 columns]

# %%
cat_ssp245.esmcat.aggregation_control.groupby_attrs = [] #to circumvent aggregate=false bug

#to avoid this issue: https://github.com/intake/intake-esm/issues/496
    #doesn't actually aggregate if we set cmip6_cat.esmcat.aggregation_control.groupby_attrs = []
kwargs = {'zarr_kwargs':{'consolidated':True,'use_cftime':True},'aggregate':True} #keyword arguments for generating dictionary of datasets from cmip6 catalogue
ddict = cat_ssp245.to_dataset_dict(**kwargs) #open datasets into dictionary
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='315' class='' max='315' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [315/315 00:51&lt;00:00]
#     </div>

# %%
ddict
# Out:
# {'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r134i1p1f1.day.sfcWind.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r134i1p1f1.day.sfcWind.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r134i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r120i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r120i1p1f1.day.psl.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r120i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r109i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r109i1p1f1.day.psl.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r109i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r16i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r16i1p1f1.day.psl.gn.v20210901.zarr.v20210901': <xarray.Dataset>
#  Dimensions:         (lat: 96, bnds: 2, lon: 192, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.57 -86.72 -84.86 ... 84.86 86.72 88.57
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(96, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(192, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2094, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r16i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2094, 96, 192), meta=np.ndarray>
#  Attributes: (12/58)
#      CDO:                              Climate Data Operators version 2.0.0rc2...
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210901
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585....,
#  'CMIP.MIROC.MIROC6.historical.r40i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC6.historical.r40i1p1f1.day.psl.gn.v20200519.zarr.v20200519': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(709, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r40i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 709, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            51134.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200519
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC6.historical.r40i1p1f1....,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r124i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r124i1p1f1.day.psl.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r124i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r113i1p1f1.day.pr.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r113i1p1f1.day.pr.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r113i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i1p1f2.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i1p1f2.day.psl.gn.v20220204.zarr.v20220204': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(4487, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r5i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 4487, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20220204
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i...,
#  'CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.day.psl.gn.v20200318.zarr.v20200318': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3545, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 3545, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            10957.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200318
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC-ES2L.historical.r4i1p1...,
#  'CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.day.psl.gn.v20191129.zarr.v20191129': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3545, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r3i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 3545, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            7305.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20191129
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC-ES2L.historical.r3i1p1...,
#  'ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r3i1p1f1.day.pr.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r3i1p1f1.day.pr.gn.v20191203.zarr.v20191203': <xarray.Dataset>
#  Dimensions:         (lat: 145, bnds: 2, lon: 192, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 87.5 88.75 90.0
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(145, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(192, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1366, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r3i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1366, 145, 192), meta=np.ndarray>
#  Attributes: (12/57)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.4.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20191203
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585....,
#  'ScenarioMIP.MIROC.MIROC6.ssp585.r45i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585.r45i1p1f1.day.psl.gn.v20200623.zarr.v20200623': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1163, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r45i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1163, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200623
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC6.ssp585.r45i1p1...,
#  'CMIP.MIROC.MIROC6.historical.r13i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.CMIP.MIROC.MIROC6.historical.r13i1p1f1.day.psl.gn.v20200519.zarr.v20200519': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(709, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r13i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 709, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            131487.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200519
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC6.historical.r13i1p1f1....,
#  'ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r128i1p1f1.day.pr.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r128i1p1f1.day.pr.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 5113)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 2087-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(284, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r128i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 284, 256, 512), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.4.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.EC-Earth-Consortium.EC-Eart...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r23i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r23i1p1f1.day.psl.gr.v20210527.zarr.v20210527': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(286, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r23i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 286, 256, 512), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_time:                      0.0
#      branch_time_in_child:             0.0
#      cmor_version:                     3.4.0
#      contact:                          cmip6-data@ec-earth.org
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210527
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r4i1p1f2.day.pr.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r4i1p1f2.day.pr.gn.v20211201.zarr.v20211201': <xarray.Dataset>
#  Dimensions:         (lat: 144, bnds: 2, lon: 192, member_id: 1,
#                       dcpp_init_year: 1, time: 102960)
#  Coordinates:
#    * lat             (lat) float64 -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(144, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(192, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2300-12-30 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1980, 144, 192), meta=np.ndarray>
#  Attributes: (12/52)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             59400.0
#      branch_time_in_parent:            59400.0
#      data_specs_version:               01.00.29
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20211201
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r4i...,
#  'CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.day.psl.gn.v20200318.zarr.v20200318': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3545, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r10i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 3545, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            32871.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200318
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC-ES2L.historical.r10i1p...,
#  'ScenarioMIP.CCCma.CanESM5-1.ssp585.r2i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.CCCma.CanESM5-1.ssp585.r2i1p1f1.day.psl.gn.v20190429.zarr.v20190429': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 31390)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(6278, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r2i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 6278, 64, 128), meta=np.ndarray>
#  Attributes: (12/66)
#      CCCma_model_hash:                 c239d945c7f6d43adf408cb779e7dc79433c2a40
#      CCCma_parent_runid:               v5.1-histens-02
#      CCCma_pycmor_hash:                not applicable
#      CCCma_runid:                      v5.1-p1-ssp585-02
#      Conventions:                      CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:        2015:01:01:00
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20190429
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.CCCma.CanESM5-1.ssp585.r2i1...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r121i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r121i1p1f1.day.psl.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r121i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'ScenarioMIP.CCCma.CanESM5-1.ssp585.r4i1p2f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.CCCma.CanESM5-1.ssp585.r4i1p2f1.day.sfcWind.gn.v20190429.zarr.v20190429': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 31390)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(6278, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p2f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 6278, 64, 128), meta=np.ndarray>
#  Attributes: (12/67)
#      CCCma_model_hash:                 c239d945c7f6d43adf408cb779e7dc79433c2a40
#      CCCma_parent_runid:               v5.1-p2-histens-04
#      CCCma_pycmor_hash:                not applicable
#      CCCma_runid:                      v5.1-p2-ssp585-04
#      Conventions:                      CF-1.7 CMIP-6.2
#      NCO:                              netCDF Operators version 5.0.5 (Homepag...
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20190429
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.CCCma.CanESM5-1.ssp585.r4i1...,
#  'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.day.sfcWind.gn.v20220204.zarr.v20220204': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(4487, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r10i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 4487, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20220204
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10...,
#  'ScenarioMIP.CCCma.CanESM5-1.ssp585.r8i1p2f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6116249679-1/CMIP6.ScenarioMIP.CCCma.CanESM5-1.ssp585.r8i1p2f1.day.sfcWind.gn.v20190429.zarr.v20190429': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 31390)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(6278, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r8i1p2f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 6278, 64, 128), meta=np.ndarray>
#  Attributes: (12/67)
#      CCCma_model_hash:                 c239d945c7f6d43adf408cb779e7dc79433c2a40
#      CCCma_parent_runid:               v5.1-p2-histens-08
#      CCCma_pycmor_hash:                not applicable
#      CCCma_runid:                      v5.1-p2-ssp585-08
#      Conventions:                      CF-1.7 CMIP-6.2
#      NCO:                              netCDF Operators version 5.0.5 (Homepag...
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20190429
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.CCCma.CanESM5-1.ssp585.r8i1...,
#  'ScenarioMIP.MIROC.MIROC6.ssp585.r49i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585.r49i1p1f1.day.psl.gn.v20200623.zarr.v20200623': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1163, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r49i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1163, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200623
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC6.ssp585.r49i1p1...,
#  'ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r17i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r17i1p1f1.day.psl.gn.v20210901.zarr.v20210901': <xarray.Dataset>
#  Dimensions:         (lat: 96, bnds: 2, lon: 192, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.57 -86.72 -84.86 ... 84.86 86.72 88.57
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(96, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(192, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2094, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r17i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2094, 96, 192), meta=np.ndarray>
#  Attributes: (12/58)
#      CDO:                              Climate Data Operators version 2.0.0rc2...
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210901
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585....,
#  'ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r3i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r3i1p1f1.day.psl.gn.v20210907.zarr.v20210907': <xarray.Dataset>
#  Dimensions:         (lat: 160, bnds: 2, lon: 320, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -89.14 -88.03 -86.91 ... 86.91 88.03 89.14
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(160, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.125 2.25 3.375 ... 356.6 357.8 358.9
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(320, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(730, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r3i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 730, 160, 320), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210907
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r3i1p...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r19i1p1f1.day.pr.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r19i1p1f1.day.pr.gr.v20210305.zarr.v20210305': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
# ...
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.4.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.EC-Earth-Consortium.EC-Eart...,
#  'ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r143i1p1f1.day.pr.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r143i1p1f1.day.pr.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 730)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 2099-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(365, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r143i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 365, 256, 512), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.4.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.EC-Earth-Consortium.EC-Eart...,
#  'CMIP.EC-Earth-Consortium.EC-Earth3.historical.r117i1p1f1.day.sfcWind.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r117i1p1f1.day.sfcWind.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 16436)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 1970-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(288, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r117i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 288, 256, 512), meta=np.ndarray>
#  Attributes: (12/48)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      cmor_version:                     3.4.0
#      comment:                          This experiment is part of SMHI's Large...
#      contact:                          cmip6-data@ec-earth.org
#      data_specs_version:               01.00.30
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.EC-Earth-Consortium.EC-Earth3.hist...,
#  'ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r138i1p1f1.day.psl.gr.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6112919295-1/CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r138i1p1f1.day.psl.gr.v20200412.zarr.v20200412': <xarray.Dataset>
#  Dimensions:         (lat: 256, bnds: 2, lon: 512, member_id: 1,
#                       dcpp_init_year: 1, time: 8400)
#  Coordinates:
#    * lat             (lat) float64 -89.46 -88.77 -88.07 ... 88.07 88.77 89.46
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(512, 2), meta=np.ndarray>
#    * time            (time) object 2078-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(420, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r138i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 420, 256, 512), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.4.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200412
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.EC-Earth-Consortium.EC-Eart...,
#  'ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r4i1p1f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6108923902-1/CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r4i1p1f1.day.sfcWind.gn.v20210907.zarr.v20210907': <xarray.Dataset>
#  Dimensions:         (lat: 160, bnds: 2, lon: 320, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -89.14 -88.03 -86.91 ... 86.91 88.03 89.14
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(160, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.125 2.25 3.375 ... 356.6 357.8 358.9
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(320, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(730, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 730, 160, 320), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210907
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r4i1p...,
#  'ScenarioMIP.MIROC.MIROC6.ssp585.r4i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6116249679-1/CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585.r4i1p1f1.day.psl.gn.v20200623.zarr.v20200623': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1163, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1163, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200623
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC6.ssp585.r4i1p1f...,
#  'CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6116249679-1/CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.day.psl.gn.v20200318.zarr.v20200318': <xarray.Dataset>
#  Dimensions:         (lat: 64, bnds: 2, lon: 128, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -87.86 -85.1 -82.31 ... 82.31 85.1 87.86
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3545, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r5i1p1f2'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 3545, 64, 128), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            14610.0
#      cmor_version:                     3.3.2
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200318
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC-ES2L.historical.r5i1p1...,
#  'CMIP.MIROC.MIROC6.historical.r49i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC6.historical.r49i1p1f1.day.psl.gn.v20200519.zarr.v20200519': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(709, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r49i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 709, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            281237.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200519
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC6.historical.r49i1p1f1....,
#  'CMIP.MIROC.MIROC6.historical.r47i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6115372254-1/CMIP6.CMIP.MIROC.MIROC6.historical.r47i1p1f1.day.psl.gn.v20200519.zarr.v20200519': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 60265)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(709, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r47i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 709, 128, 256), meta=np.ndarray>
#  Attributes: (12/54)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            266627.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20200519
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.MIROC.MIROC6.historical.r47i1p1f1....}

# %%
for key,ds in ddict.items():
    print(ds.attrs)
# Out:
# {'Conventions': 'CF-1.7 CMIP-6.2', 'activity_id': 'CMIP', 'branch_method': 'standard', 'branch_time_in_child': 0.0, 'branch_time_in_parent': 134685.0, 'cmor_version': '3.5.0', 'contact': 'Lijuan Li (ljli@mail.iap.ac.cn)', 'data_specs_version': '01.00.31', 'experiment': 'all-forcing simulation of the recent past', 'experiment_id': 'historical', 'external_variables': 'areacella', 'forcing_index': 1, 'frequency': 'day', 'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.CAS.FGOALS-g3.historical.none.r3i1p1f1', 'grid': 'native atmosphere area-weighted latxlon grid (80x180 latxlon)', 'grid_label': 'gn', 'initialization_index': 1, 'institution': 'Chinese Academy of Sciences, Beijing 100029, China', 'institution_id': 'CAS', 'license': 'CMIP6 model data produced by Lawrence Livermore PCMDI is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https:///pcmdi.llnl.gov/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.', 'mip_era': 'CMIP6', 'nominal_resolution': '250 km', 'parent_activity_id': 'CMIP', 'parent_experiment_id': 'piControl', 'parent_mip_era': 'CMIP6', 'parent_source_id': 'FGOALS-g3', 'parent_time_units': 'days since 0001-01-01', 'parent_variant_label': 'r1i1p1f1', 'physics_index': 1, 'product': 'model-output', 'realization_index': 3, 'realm': 'atmos', 'run_variant': '3rd realization', 'source': 'FGOALS-g3 (2017): \naerosol: none\natmos: GAMIL2 (180 x 90 longitude/latitude; 26 levels; top level 2.19hPa)\natmosChem: none\nland: CLM4.0\nlandIce: none\nocean: LICOM3.0 (LICOM3.0, tripolar primarily 1deg; 360 x 218 longitude/latitude; 30 levels; top grid cell 0-10 m)\nocnBgchem: none\nseaIce: CICE4.0', 'source_id': 'FGOALS-g3', 'source_type': 'AOGCM', 'sub_experiment': 'none', 'sub_experiment_id': 'none', 'table_id': 'day', 'table_info': 'Creation Date:(24 July 2019) MD5:3039b0071259358b3c55557c5f3d21bf', 'title': 'FGOALS-g3 output prepared for CMIP6', 'variable_id': 'psl', 'variant_label': 'r3i1p1f1', 'intake_esm_vars': ['psl'], 'intake_esm_attrs:activity_id': 'CMIP', 'intake_esm_attrs:institution_id': 'CAS', 'intake_esm_attrs:source_id': 'FGOALS-g3', 'intake_esm_attrs:experiment_id': 'historical', 'intake_esm_attrs:member_id': 'r3i1p1f1', 'intake_esm_attrs:table_id': 'day', 'intake_esm_attrs:variable_id': 'psl', 'intake_esm_attrs:grid_label': 'gn', 'intake_esm_attrs:zstore': 'gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.psl.gn.v20190827.zarr', 'intake_esm_attrs:version': 'v20190827', 'intake_esm_attrs:_data_format_': 'zarr', 'intake_esm_dataset_key': 'CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.psl.gn.v20190827.zarr.v20190827'}
# {'Conventions': 'CF-1.7 CMIP-6.2', 'activity_id': 'CMIP', 'branch_method': 'standard', 'branch_time_in_child': 0.0, 'branch_time_in_parent': 134685.0, 'cmor_version': '3.5.0', 'contact': 'Lijuan Li (ljli@mail.iap.ac.cn)', 'data_specs_version': '01.00.31', 'experiment': 'all-forcing simulation of the recent past', 'experiment_id': 'historical', 'external_variables': 'areacella', 'forcing_index': 1, 'frequency': 'day', 'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.CAS.FGOALS-g3.historical.none.r4i1p1f1', 'grid': 'native atmosphere area-weighted latxlon grid (80x180 latxlon)', 'grid_label': 'gn', 'history': '2019-10-28T13:17:56Z ;rewrote data to be consistent with CMIP for variable clt found in table day.', 'initialization_index': 1, 'institution': 'Chinese Academy of Sciences, Beijing 100029, China', 'institution_id': 'CAS', 'license': 'CMIP6 model data produced by Lawrence Livermore PCMDI is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https:///pcmdi.llnl.gov/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.', 'mip_era': 'CMIP6', 'nominal_resolution': '250 km', 'parent_activity_id': 'CMIP', 'parent_experiment_id': 'piControl', 'parent_mip_era': 'CMIP6', 'parent_source_id': 'FGOALS-g3', 'parent_time_units': 'days since 0001-01-01', 'parent_variant_label': 'r1i1p1f1', 'physics_index': 1, 'product': 'model-output', 'realization_index': 4, 'realm': 'atmos', 'run_variant': '3rd realization', 'source': 'FGOALS-g3 (2017): \naerosol: none\natmos: GAMIL2 (180 x 90 longitude/latitude; 26 levels; top level 2.19hPa)\natmosChem: none\nland: CLM4.0\nlandIce: none\nocean: LICOM3.0 (LICOM3.0, tripolar primarily 1deg; 360 x 218 longitude/latitude; 30 levels; top grid cell 0-10 m)\nocnBgchem: none\nseaIce: CICE4.0', 'source_id': 'FGOALS-g3', 'source_type': 'AOGCM', 'sub_experiment': 'none', 'sub_experiment_id': 'none', 'table_id': 'day', 'table_info': 'Creation Date:(24 July 2019) MD5:70649eeb16bc90c431e35b583fac7375', 'title': 'FGOALS-g3 output prepared for CMIP6', 'variable_id': 'psl', 'variant_label': 'r4i1p1f1', 'intake_esm_vars': ['psl'], 'intake_esm_attrs:activity_id': 'CMIP', 'intake_esm_attrs:institution_id': 'CAS', 'intake_esm_attrs:source_id': 'FGOALS-g3', 'intake_esm_attrs:experiment_id': 'historical', 'intake_esm_attrs:member_id': 'r4i1p1f1', 'intake_esm_attrs:table_id': 'day', 'intake_esm_attrs:variable_id': 'psl', 'intake_esm_attrs:grid_label': 'gn', 'intake_esm_attrs:zstore': 'gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.psl.gn.v20191029.zarr', 'intake_esm_attrs:version': 'v20191029', 'intake_esm_attrs:_data_format_': 'zarr', 'intake_esm_dataset_key': 'CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.psl.gn.v20191029.zarr.v20191029'}
# {'Conventions': 'CF-1.7 CMIP-6.2', 'activity_id': 'CMIP', 'branch_method': 'standard', 'branch_time_in_child': 0.0, 'branch_time_in_parent': 134685.0, 'cmor_version': '3.5.0', 'contact': 'Lijuan Li (ljli@mail.iap.ac.cn)', 'data_specs_version': '01.00.31', 'experiment': 'all-forcing simulation of the recent past', 'experiment_id': 'historical', 'external_variables': 'areacella', 'forcing_index': 1, 'frequency': 'day', 'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.CAS.FGOALS-g3.historical.none.r3i1p1f1', 'grid': 'native atmosphere area-weighted latxlon grid (80x180 latxlon)', 'grid_label': 'gn', 'initialization_index': 1, 'institution': 'Chinese Academy of Sciences, Beijing 100029, China', 'institution_id': 'CAS', 'license': 'CMIP6 model data produced by Lawrence Livermore PCMDI is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https:///pcmdi.llnl.gov/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.', 'mip_era': 'CMIP6', 'nominal_resolution': '250 km', 'parent_activity_id': 'CMIP', 'parent_experiment_id': 'piControl', 'parent_mip_era': 'CMIP6', 'parent_source_id': 'FGOALS-g3', 'parent_time_units': 'days since 0001-01-01', 'parent_variant_label': 'r1i1p1f1', 'physics_index': 1, 'product': 'model-output', 'realization_index': 3, 'realm': 'atmos', 'run_variant': '3rd realization', 'source': 'FGOALS-g3 (2017): \naerosol: none\natmos: GAMIL2 (180 x 90 longitude/latitude; 26 levels; top level 2.19hPa)\natmosChem: none\nland: CLM4.0\nlandIce: none\nocean: LICOM3.0 (LICOM3.0, tripolar primarily 1deg; 360 x 218 longitude/latitude; 30 levels; top grid cell 0-10 m)\nocnBgchem: none\nseaIce: CICE4.0', 'source_id': 'FGOALS-g3', 'source_type': 'AOGCM', 'sub_experiment': 'none', 'sub_experiment_id': 'none', 'table_id': 'day', 'table_info': 'Creation Date:(24 July 2019) MD5:3039b0071259358b3c55557c5f3d21bf', 'title': 'FGOALS-g3 output prepared for CMIP6', 'variable_id': 'sfcWind', 'variant_label': 'r3i1p1f1', 'intake_esm_vars': ['sfcWind'], 'intake_esm_attrs:activity_id': 'CMIP', 'intake_esm_attrs:institution_id': 'CAS', 'intake_esm_attrs:source_id': 'FGOALS-g3', 'intake_esm_attrs:experiment_id': 'historical', 'intake_esm_attrs:member_id': 'r3i1p1f1', 'intake_esm_attrs:table_id': 'day', 'intake_esm_attrs:variable_id': 'sfcWind', 'intake_esm_attrs:grid_label': 'gn', 'intake_esm_attrs:zstore': 'gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.sfcWind.gn.v20190827.zarr', 'intake_esm_attrs:version': 'v20190827', 'intake_esm_attrs:_data_format_': 'zarr', 'intake_esm_dataset_key': 'CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.sfcWind.gn.v20190827.zarr.v20190827'}
# {'Conventions': 'CF-1.7 CMIP-6.2', 'activity_id': 'CMIP', 'branch_method': 'standard', 'branch_time_in_child': 0.0, 'branch_time_in_parent': 134685.0, 'cmor_version': '3.5.0', 'contact': 'Lijuan Li (ljli@mail.iap.ac.cn)', 'data_specs_version': '01.00.31', 'experiment': 'all-forcing simulation of the recent past', 'experiment_id': 'historical', 'external_variables': 'areacella', 'forcing_index': 1, 'frequency': 'day', 'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.CAS.FGOALS-g3.historical.none.r4i1p1f1', 'grid': 'native atmosphere area-weighted latxlon grid (80x180 latxlon)', 'grid_label': 'gn', 'history': '2019-10-28T13:17:56Z ;rewrote data to be consistent with CMIP for variable clt found in table day.', 'initialization_index': 1, 'institution': 'Chinese Academy of Sciences, Beijing 100029, China', 'institution_id': 'CAS', 'license': 'CMIP6 model data produced by Lawrence Livermore PCMDI is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at https:///pcmdi.llnl.gov/. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.', 'mip_era': 'CMIP6', 'nominal_resolution': '250 km', 'parent_activity_id': 'CMIP', 'parent_experiment_id': 'piControl', 'parent_mip_era': 'CMIP6', 'parent_source_id': 'FGOALS-g3', 'parent_time_units': 'days since 0001-01-01', 'parent_variant_label': 'r1i1p1f1', 'physics_index': 1, 'product': 'model-output', 'realization_index': 4, 'realm': 'atmos', 'run_variant': '3rd realization', 'source': 'FGOALS-g3 (2017): \naerosol: none\natmos: GAMIL2 (180 x 90 longitude/latitude; 26 levels; top level 2.19hPa)\natmosChem: none\nland: CLM4.0\nlandIce: none\nocean: LICOM3.0 (LICOM3.0, tripolar primarily 1deg; 360 x 218 longitude/latitude; 30 levels; top grid cell 0-10 m)\nocnBgchem: none\nseaIce: CICE4.0', 'source_id': 'FGOALS-g3', 'source_type': 'AOGCM', 'sub_experiment': 'none', 'sub_experiment_id': 'none', 'table_id': 'day', 'table_info': 'Creation Date:(24 July 2019) MD5:70649eeb16bc90c431e35b583fac7375', 'title': 'FGOALS-g3 output prepared for CMIP6', 'variable_id': 'sfcWind', 'variant_label': 'r4i1p1f1', 'intake_esm_vars': ['sfcWind'], 'intake_esm_attrs:activity_id': 'CMIP', 'intake_esm_attrs:institution_id': 'CAS', 'intake_esm_attrs:source_id': 'FGOALS-g3', 'intake_esm_attrs:experiment_id': 'historical', 'intake_esm_attrs:member_id': 'r4i1p1f1', 'intake_esm_attrs:table_id': 'day', 'intake_esm_attrs:variable_id': 'sfcWind', 'intake_esm_attrs:grid_label': 'gn', 'intake_esm_attrs:zstore': 'gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.sfcWind.gn.v20191029.zarr', 'intake_esm_attrs:version': 'v20191029', 'intake_esm_attrs:_data_format_': 'zarr', 'intake_esm_dataset_key': 'CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.sfcWind.gn.v20191029.zarr.v20191029'}
# {'Conventions': 'CF-1.7 CMIP-6.2', 'activity_id': 'ScenarioMIP', 'branch_method': 'standard', 'branch_time_in_child': 60265.0, 'branch_time_in_parent': 60265.0, 'cmor_version': '3.4.0', 'comment': "This experiment is part of SMHI's Large Ensemble. All experiments of the ensemble were started from a set of initial conditions in 1970.", 'contact': 'cmip6-data@ec-earth.org', 'data_specs_version': '01.00.30', 'experiment': 'update of RCP8.5 based on SSP5', 'experiment_id': 'ssp585', 'external_variables': 'areacella', 'forcing_index': 1, 'frequency': 'day', 'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.EC-Earth-Consortium.EC-Earth3.ssp585.none.r125i1p1f1', 'grid': 'T255L91-ORCA1L75', 'grid_label': 'gr', 'initialization_index': 1, 'institution': 'AEMET, Spain; BSC, Spain; CNR-ISAC, Italy; DMI, Denmark; ENEA, Italy; FMI, Finland; Geomar, Germany; ICHEC, Ireland; ICTP, Italy; IDL, Portugal; IMAU, The Netherlands; IPMA, Portugal; KIT, Karlsruhe, Germany; KNMI, The Netherlands; Lund University, Sweden; Met Eireann, Ireland; NLeSC, The Netherlands; NTNU, Norway; Oxford University, UK; surfSARA, The Netherlands; SMHI, Sweden; Stockholm University, Sweden; Unite ASTR, Belgium; University College Dublin, Ireland; University of Bergen, Norway; University of Copenhagen, Denmark; University of Helsinki, Finland; University of Santiago de Compostela, Spain; Uppsala University, Sweden; Utrecht University, The Netherlands; Vrije Universiteit Amsterdam, the Netherlands; Wageningen University, The Netherlands. Mailing address: EC-Earth consortium, Rossby Center, Swedish Meteorological and Hydrological Institute/SMHI, SE-601 76 Norrkoping, Sweden', 'institution_id': 'EC-Earth-Consortium', 'license': 'CMIP6 model data produced by EC-Earth-Consortium is licensed under a Creative Commons Attribution-ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file) and at http://www.ec-earth.org. The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.', 'mip_era': 'CMIP6', 'nominal_resolution': '100 km', 'parent_activity_id': 'CMIP', 'parent_experiment_id': 'historical', 'parent_mip_era': 'CMIP6', 'parent_source_id': 'EC-Earth3', 'parent_time_units': 'days since 1850-01-01', 'parent_variant_label': 'r125i1p1f1', 'physics_index': 1, 'product': 'model-output', 'realization_index': 125, 'realm': 'atmos', 'source': 'EC-Earth3 (2019): \naerosol: none\natmos: IFS cy36r4 (TL255, linearly reduced Gaussian grid equivalent to 512 x 256 longitude/latitude; 91 levels; top level 0.01 hPa)\natmosChem: none\nland: HTESSEL (land surface scheme built in IFS)\nlandIce: none\nocean: NEMO3.6 (ORCA1 tripolar primarily 1 deg with meridional refinement down to 1/3 degree in the tropics; 362 x 292 longitude/latitude; 75 levels; top grid cell 0-1 m)\nocnBgchem: none\nseaIce: LIM3', 'source_id': 'EC-Earth3', 'source_type': 'AOGCM', 'sub_experiment': 'none', 'sub_experiment_id': 'none', 'table_id': 'day', 'table_info': 'Creation Date:(09 May 2019) MD5:1d844b3662ef3f929a5d7e5fa67a5d37', 'title': 'EC-Earth3 output prepared for CMIP6', 'variable_id': 'psl', 'variant_label': 'r125i1p1f1', 'intake_esm_vars': ['psl'], 'intake_esm_attrs:activity_id': 'ScenarioMIP', 'intake_esm_attrs:institution_id': 'EC-Earth-Consortium', 'intake_esm_attrs:source_id': 'EC-Earth3', 'intake_esm_attrs:experiment_id': 'ssp585', 'intake_esm_attrs:member_id': 'r125i1p1f1', 'intake_esm_attrs:table_id': 'day', 'intak ...

# %%
ddict
# Out:
# {'CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.psl.gn.v20191029.zarr.v20191029': <xarray.Dataset>
#  Dimensions:         (lat: 80, bnds: 2, lon: 180, member_id: 1,
#                       dcpp_init_year: 1, time: 60225)
#  Coordinates:
#    * lat             (lat) float64 -90.0 -84.82 -80.72 ... 80.72 84.82 90.0
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(80, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2409, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2409, 80, 180), meta=np.ndarray>
#  Attributes: (12/57)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            134685.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20191029
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.CAS.FGOALS-g3.historical.r4i1p1f1....,
#  'ScenarioMIP.MIROC.MIROC6.ssp245.r37i1p1f1.day.pr.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6102440203-1/CMIP6.ScenarioMIP.MIROC.MIROC6.ssp245.r37i1p1f1.day.pr.gn.v20210917.zarr.v20210917': <xarray.Dataset>
#  Dimensions:         (lat: 128, bnds: 2, lon: 256, member_id: 1,
#                       dcpp_init_year: 1, time: 31411)
#  Coordinates:
#    * lat             (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#    * time            (time) object 2015-01-01 12:00:00 ... 2100-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(1163, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r37i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      pr              (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1163, 128, 256), meta=np.ndarray>
#  Attributes: (12/53)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      ScenarioMIP
#      branch_method:                    standard
#      branch_time_in_child:             60265.0
#      branch_time_in_parent:            60265.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     pr
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20210917
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           ScenarioMIP.MIROC.MIROC6.ssp245.r37i1p1...,
#  'CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.sfcWind.gn.v20190827.zarr.v20190827': <xarray.Dataset>
#  Dimensions:         (lat: 80, bnds: 2, lon: 180, member_id: 1,
#                       dcpp_init_year: 1, time: 60225)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -90.0 -84.82 -80.72 ... 80.72 84.82 90.0
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(80, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2409, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r3i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2409, 80, 180), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            134685.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20190827
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.CAS.FGOALS-g3.historical.r3i1p1f1....,
#  'CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.psl.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r3i1p1f1.day.psl.gn.v20190827.zarr.v20190827': <xarray.Dataset>
#  Dimensions:         (lat: 80, bnds: 2, lon: 180, member_id: 1,
#                       dcpp_init_year: 1, time: 60225)
#  Coordinates:
#    * lat             (lat) float64 -90.0 -84.82 -80.72 ... 80.72 84.82 90.0
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(80, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2409, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r3i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      psl             (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2409, 80, 180), meta=np.ndarray>
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            134685.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     psl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20190827
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.CAS.FGOALS-g3.historical.r3i1p1f1....,
#  'CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.sfcWind.gn.gs://leap-persistent-ro/data-library/cmip6-testing/a618127503-6091056444-4/CMIP6.CMIP.CAS.FGOALS-g3.historical.r4i1p1f1.day.sfcWind.gn.v20191029.zarr.v20191029': <xarray.Dataset>
#  Dimensions:         (lat: 80, bnds: 2, lon: 180, member_id: 1,
#                       dcpp_init_year: 1, time: 60225)
#  Coordinates:
#      height          float64 ...
#    * lat             (lat) float64 -90.0 -84.82 -80.72 ... 80.72 84.82 90.0
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(80, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * time            (time) object 1850-01-01 12:00:00 ... 2014-12-31 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(2409, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r4i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      sfcWind         (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 2409, 80, 180), meta=np.ndarray>
#  Attributes: (12/57)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      CMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            134685.0
#      cmor_version:                     3.5.0
#      ...                               ...
#      intake_esm_attrs:variable_id:     sfcWind
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://leap-persistent-ro/data-library/cm...
#      intake_esm_attrs:version:         v20191029
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           CMIP.CAS.FGOALS-g3.historical.r4i1p1f1....}
